# %%
import numpy as np
import pandas as pd

df = pd.read_csv('weatherHistory_v1.csv')
df.describe()
# Out:
#        Temperature (C)
# count     59538.000000
# mean         11.832714
# std           9.805586
# min         -21.822222
# 25%           4.061111
# 50%          12.038889
# 75%          18.877778
# max          39.588889

# %%
print(df.size)
print(df.dtypes)
print(df.shape)
# Out:
# 140000
# Formatted Date      object
# Temperature (C)    float64
# dtype: object
# (70000, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Formatted Date   70000 non-null  object
#  1   Temperature (C)  59538 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.1+ MB

# %%
df['Temperature (C)'].plot.kde(0.2)
# Out:
# <Axes: ylabel='Density'>

# %%
df['Temperature (C)'].hist()
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ## Visualization

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('weatherHistory_df.csv')
df[0:100]['Temperature (C)'].plot()
# Out:
# <Axes: >

# %%
df = pd.read_csv('weatherHistory_df.csv')
df[0:100]['Temperature (C)'].ffill().plot()
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('weatherHistory_df.csv')
df[0:100]['Temperature (C)'].ffill().rolling(window=5).mean().plot()
# Out:
# <Axes: >
