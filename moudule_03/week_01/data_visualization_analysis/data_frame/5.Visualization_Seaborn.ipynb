# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('iris.csv')
print(data.shape)
# Out:
# (150, 5)

# %%
sns.jointplot(x="SepalLength", y="PetalWidth", 
              data=data, hue="Name")
plt.show()
